# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolo11n.pt")  # Load an official model or custom model
model = YOLO("yolov8n.pt")

# Export the model
#model.export(format="edgetpu", imgsz=160)
model.export(format="edgetpu", nms=False, imgsz=160)
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 160, 160) BCHW and output shape(s) (1, 84, 525) (6.2 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 1.1s, saved as 'yolov8n.onnx' (12.1 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.5...
# Saved artifact at 'yolov8n_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 160, 160, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 84, 525), dtype=tf.float32, name=None)
# Captures:
#   137408022337232: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
# ...
